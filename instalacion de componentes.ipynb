# %%
import numpy as np
from scipy import misc
import imageio
import matplotlib.pyplot as plt

# %%
# load data
rgbIn = imageio.imread('lena512.png')

# %%
# show data
plt.figure(0)
plt.imshow(rgbIn)
